# %% [markdown]
# <a href="https://colab.research.google.com/github/christy5165/Denoising_Autoencoder.ipynb/blob/main/VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                   # Used for numerical operations and handling arrays
import matplotlib.pyplot as plt      # Used for plotting loss curves and visualizing generated images
import torch                         # The core PyTorch library for tensor computations
import torch.nn as nn                # Provides building blocks for designing the neural network layers (Encoder/Decoder)
import torch.optim as optim          # Contains optimization algorithms like Adam or SGD to update model weights
import torchvision                   # Provides access to popular datasets (like MNIST) and image transformations
from torchvision import transforms   # Used for preprocessing images (e.g., converting to tensors or normalizing)
